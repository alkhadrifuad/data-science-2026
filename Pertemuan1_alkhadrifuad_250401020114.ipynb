# %% [markdown]
# <a href="https://colab.research.google.com/github/alkhadrifuad/data-science-2026/blob/master/Pertemuan1_alkhadrifuad_250401020114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Output Sederhana
print("Hello Mahasiswa Data Science Unsia")
# Out:
# Hello Mahasiswa Data Science Unsia

# %%
#Variabel dan typedata
nama ="Al khadri Fuad"
prodi = "Informatika"
angkatan = 2025
NIM = 250401020114
print(nama)
print(prodi)
print(angkatan)
print(NIM)
print(f"Hallo nama saya {nama} dari Prodi {prodi} dan angkatan {angkatan} dengan NIM {NIM}")
# Out:
# Al khadri Fuad
# Informatika
# 2025
# 250401020114
# Hallo nama saya Al khadri Fuad dari Prodi Informatika dan angkatan 2025 dengan NIM 250401020114

# %%
#Perulangan dan list
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub

# %%
#fungsi
def perkenalan(nama, prodi, angkatan):
    return print (f"Hai! nama Saya {nama} dari Prodi {prodi}, dan angkatan {angkatan}. dengan NIM {NIM}")

perkenalan("Al Khadri Fuad", "Informatika", 2025)
# Out:
# Hai! nama Saya Al Khadri Fuad dari Prodi Informatika, dan angkatan 2025. dengan NIM 250401020114
